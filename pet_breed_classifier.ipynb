# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasmash/pet-breed-classifier/blob/main/pet_breed_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Vasmash/pet-breed-classifier
# Out:
# Cloning into 'pet-breed-classifier'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.

# %% [markdown]
# Here is my work.
